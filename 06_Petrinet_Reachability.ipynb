# %% [markdown]
# # Specification of a Petrinet and Reachbility Graph

# %%
import pandas as pd
import numpy as np
from datetime import date
from IPython.display import Markdown, display
import matplotlib.pyplot as plt
import seaborn as sns

#!pip install pm4py --user
from pm4py.objects.conversion.log import converter as log_converter
from pm4py.objects.log.importer.xes import importer as xes_importer

# process mining 
from pm4py.algo.discovery.alpha import algorithm as alpha_miner
from pm4py.algo.discovery.inductive import algorithm as inductive_miner
from pm4py.algo.discovery.heuristics import algorithm as heuristics_miner
from pm4py.algo.discovery.dfg import algorithm as dfg_discovery
from pm4py.algo.discovery.footprints import algorithm as footprints_discovery


# viz
from pm4py.visualization.petri_net import visualizer as pn_visualizer
from pm4py.visualization.footprints import visualizer as fp_visualizer
from pm4py.visualization.transition_system import visualizer as ts_visualizer
from pm4py.visualization.process_tree import visualizer as pt_visualizer
from pm4py.visualization.heuristics_net import visualizer as hn_visualizer
from pm4py.visualization.dfg import visualizer as dfg_visualization

# misc 
from pm4py.objects.petri_net.utils import reachability_graph
from pm4py.objects.conversion.process_tree import converter as pt_converter
from pm4py.objects.petri_net.obj import PetriNet, Marking
from pm4py.algo.simulation.playout.petri_net import algorithm as simulator

import pm4py
# Out:
# Collecting pm4py
#   Downloading pm4py-2.7.4-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 28.8 MB/s eta 0:00:00:00:01
# Collecting deprecation (from pm4py)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting graphviz (from pm4py)
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 1.8 MB/s eta 0:00:00
# Collecting intervaltree (from pm4py)
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lxml (from pm4py)
#   Downloading lxml-4.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 62.5 MB/s eta 0:00:00:00:01
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (from pm4py) (3.7.1)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.10/site-packages (from pm4py) (3.1)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from pm4py) (1.24.3)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.10/site-packages (from pm4py) (2.0.1)
# Collecting pydotplus (from pm4py)
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.7/278.7 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytz in /home/codespace/.local/lib/python3.10/site-packages (from pm4py) (2023.3)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.10/site-packages (from pm4py) (1.10.1)
# Collecting stringdist (from pm4py)
#   Downloading StringDist-1.0.9.tar.gz (7.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tqdm (from pm4py)
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 2.8 MB/s eta 0:00:00
# Collecting cvxopt (from pm4py)
#   Downloading cvxopt-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 51.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from deprecation->pm4py) (23.1)
# Collecting sortedcontainers<3.0,>=2.0 (from intervaltree->pm4py)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pm4py) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pm4py) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pm4py) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pm4py) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pm4py) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pm4py) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pm4py) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->pm4py) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->pm4py) (1.16.0)
# Building wheels for collected packages: intervaltree, pydotplus, stringdist
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26099 sha256=669199c9665662133e52f1efee1eebc78c4929dbe9623f222d39e9da92640de4
#   Stored in directory: /home/codespace/.cache/pip/wheels/fa/80/8c/43488a924a046b733b64de3fac99252674c892a4c3801c0a61
#   Building wheel for pydotplus (setup.py) ... done
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24554 sha256=e29560bb6f14f23ff0481bbd1fdaf82fb38c3f2678bda4f7f4adbfe4386e0a40
#   Stored in directory: /home/codespace/.cache/pip/wheels/69/b2/67/08f0eef649af92df772c09f451558298e07fab1bc7cdf33db0
#   Building wheel for stringdist (setup.py) ... done
#   Created wheel for stringdist: filename=StringDist-1.0.9-cp310-cp310-linux_x86_64.whl size=25071 sha256=48a679fe238a672f4f1d39bbba16c54f1b645821c68c3d347f27260ccc724dba
#   Stored in directory: /home/codespace/.cache/pip/wheels/79/25/0a/4a0c2c7af31a8b473f6e10e30312396f31ae899722600d7b99
# Successfully built intervaltree pydotplus stringdist
# Installing collected packages: stringdist, sortedcontainers, tqdm, pydotplus, lxml, intervaltree, graphviz, deprecation, cvxopt, pm4py
# Successfully installed cvxopt-1.3.1 deprecation-2.1.0 graphviz-0.20.1 intervaltree-3.1.0 lxml-4.9.2 pm4py-2.7.4 pydotplus-2.0.2 sortedcontainers-2.4.0 stringdist-1.0.9 tqdm-4.65.0
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
# please issue the following comand in a terminal
# conda install python-graphviz

# %% [markdown]
# The following code models and analyses a simple process in a doctor's office. A patient first waits to be served. Than she either receives consultation, makes an appointment or gets a prescription.

# %%
net = PetriNet("doctor_net")

# %%
# creating places: source, p_1 and sink place
source = PetriNet.Place("source")
sink = PetriNet.Place("sink")
p_1 = PetriNet.Place("p_1")
# add the places to the Petri Net
net.places.add(source)
net.places.add(sink)
net.places.add(p_1)

# %%
# Create transitions
t_1 = PetriNet.Transition("waiting", "waiting")
t_2 = PetriNet.Transition("appointment", "appointment")
t_3 = PetriNet.Transition("prescription", "prescription")
t_4 = PetriNet.Transition("consultation", "consultation")

# Add the transitions to the Petri Net
net.transitions.add(t_1)
net.transitions.add(t_2)
net.transitions.add(t_3)
net.transitions.add(t_4)

# %%
# Add arcs
from pm4py.objects.petri_net.utils import petri_utils
petri_utils.add_arc_from_to(source, t_1, net)
petri_utils.add_arc_from_to(t_1, p_1, net)
petri_utils.add_arc_from_to(p_1, t_2, net)
petri_utils.add_arc_from_to(t_2, sink, net)
petri_utils.add_arc_from_to(p_1, t_3, net)
petri_utils.add_arc_from_to(t_3, sink, net)
petri_utils.add_arc_from_to(p_1, t_4, net)
petri_utils.add_arc_from_to(t_4, sink, net)
# Out:
# (consultation, 'consultation')->sink

# %%
# Adding tokens
initial_marking = Marking()
initial_marking[source] = 1
final_marking = Marking()
final_marking[sink] = 1

# %%
pm4py.view_petri_net(net, initial_marking, final_marking)

# %%
# next we create a reachability graph for the petri net
ts = reachability_graph.construct_reachability_graph(net, initial_marking)

# %%
gviz = ts_visualizer.apply(ts)
ts_visualizer.view(gviz)

# %%
# play out all possible traces from the petri net
simulated_log = simulator.apply(net, initial_marking, variant=simulator.Variants.EXTENSIVE)
for trac in simulated_log:
    print(trac.attributes["concept:name"])
    # iterate over the activities (i.e. the transitions) of the trace
    for act in trac:
        print(act)
# Out:
# 0
# {'concept:name': 'waiting', 'time:timestamp': datetime.datetime(1970, 4, 26, 17, 46, 41)}
# {'concept:name': 'appointment', 'time:timestamp': datetime.datetime(1970, 4, 26, 17, 46, 42)}
# 1
# {'concept:name': 'waiting', 'time:timestamp': datetime.datetime(1970, 4, 26, 17, 46, 43)}
# {'concept:name': 'consultation', 'time:timestamp': datetime.datetime(1970, 4, 26, 17, 46, 44)}
# 2
# {'concept:name': 'waiting', 'time:timestamp': datetime.datetime(1970, 4, 26, 17, 46, 45)}
# {'concept:name': 'prescription', 'time:timestamp': datetime.datetime(1970, 4, 26, 17, 46, 46)}
